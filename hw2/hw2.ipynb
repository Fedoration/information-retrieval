# %%
import ssl
import json
from collections import defaultdict
import pickle

import nltk
from nltk import bigrams
from nltk.corpus import stopwords
from pymystem3 import Mystem

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")

with open("../naked_science_corpus.json", "r") as f:
    data = json.load(f)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/falaputin2/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/falaputin2/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/falaputin2/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
Stemmer = Mystem()


def lemmatize_sentence(text):
    lemmas = Stemmer.lemmatize(text)
    return "".join(lemmas).strip()


def tokenize_text(text, lemmatize=False):
    if lemmatize:
        text = lemmatize_sentence(text)

    tokens = nltk.word_tokenize(text.lower())
    clean_tokens = [
        word
        for word in tokens
        if word.isalnum() and word not in stopwords.words("russian")
    ]

    return clean_tokens


def extract_bigrams(text):
    return list(bigrams(text))

# %%
bigram_counts = defaultdict(int)

for article in data:
    if article["text"] is None:
        continue

    text = article["text"]
    tokens = tokenize_text(text)
    text_bigrams = extract_bigrams(tokens)

    for bigram in text_bigrams:
        bigram_counts[bigram] += 1


sorted_bigrams = sorted(bigram_counts.items(), key=lambda x: x[1], reverse=True)
for bigram, count in sorted_bigrams[:15]:
    print("Bigram:", bigram, "Count:", count)
# Out:
# Bigram: ('лет', 'назад') Count: 900
# Bigram: ('таким', 'образом') Count: 734
# Bigram: ('сих', 'пор') Count: 566
# Bigram: ('результаты', 'исследования') Count: 512
# Bigram: ('исследование', 'опубликовано') Count: 512
# Bigram: ('опубликовано', 'журнале') Count: 471
# Bigram: ('опубликована', 'журнале') Count: 426
# Bigram: ('миллионов', 'лет') Count: 411
# Bigram: ('пермского', 'политеха') Count: 389
# Bigram: ('нашей', 'эры') Count: 389
# Bigram: ('научный', 'сотрудник') Count: 377
# Bigram: ('тысяч', 'лет') Count: 363
# Bigram: ('авторы', 'работы') Count: 356
# Bigram: ('опубликованной', 'журнале') Count: 352
# Bigram: ('опубликованы', 'журнале') Count: 352

# %%
with open("bigram_counts.pkl", "wb") as f:
    pickle.dump(bigram_counts, f)

with open("sorted_bigram_counts.pkl", "wb") as f:
    pickle.dump(sorted_bigrams, f)

# %% [markdown]
# Лемматизация

# %%
bigram_counts = defaultdict(int)

for article in data:
    if article["text"] is None:
        continue

    text = article["text"]
    tokens = tokenize_text(text, lemmatize=True)
    text_bigrams = extract_bigrams(tokens)

    for bigram in text_bigrams:
        bigram_counts[bigram] += 1


sorted_bigrams = sorted(bigram_counts.items(), key=lambda x: x[1], reverse=True)
for bigram, count in sorted_bigrams[:15]:
    print("Bigram:", bigram, "Count:", count)
# Out:
# Bigram: ('опубликовывать', 'журнал') Count: 1956
# Bigram: ('исследование', 'опубликовывать') Count: 980
# Bigram: ('год', 'назад') Count: 931
# Bigram: ('результат', 'исследование') Count: 741
# Bigram: ('миллион', 'год') Count: 579
# Bigram: ('сей', 'пора') Count: 567
# Bigram: ('который', 'мочь') Count: 549
# Bigram: ('автор', 'работа') Count: 537
# Bigram: ('автор', 'исследование') Count: 534
# Bigram: ('окружающий', 'среда') Count: 527
# Bigram: ('друг', 'друг') Count: 526
# Bigram: ('тысяча', 'год') Count: 480
# Bigram: ('статья', 'опубликовывать') Count: 447
# Bigram: ('работа', 'опубликовывать') Count: 438
# Bigram: ('новый', 'работа') Count: 419

# %%
sorted_bigrams
# Out:
# [(('опубликовывать', 'журнал'), 1956),
#  (('исследование', 'опубликовывать'), 980),
#  (('год', 'назад'), 931),
#  (('результат', 'исследование'), 741),
#  (('миллион', 'год'), 579),
#  (('сей', 'пора'), 567),
#  (('который', 'мочь'), 549),
#  (('автор', 'работа'), 537),
#  (('автор', 'исследование'), 534),
#  (('окружающий', 'среда'), 527),
#  (('друг', 'друг'), 526),
#  (('тысяча', 'год'), 480),
#  (('статья', 'опубликовывать'), 447),
#  (('работа', 'опубликовывать'), 438),
#  (('новый', 'работа'), 419),
#  (('научный', 'сотрудник'), 408),
#  (('пермский', 'политех'), 392),
#  (('наш', 'эра'), 390),
#  (('это', 'позволять'), 387),
#  (('это', 'мочь'), 371),
#  (('черный', 'дыра'), 369),
#  (('искусственный', 'интеллект'), 365),
#  (('точка', 'зрение'), 358),
#  (('журнал', 'nature'), 357),
#  (('исследование', 'показывать'), 351),
#  (('автор', 'новый'), 345),
#  (('большой', 'количество'), 338),
#  (('2022', 'год'), 338),
#  (('journal', 'of'), 337),
#  (('самый', 'дело'), 334),
#  (('новый', 'исследование'), 303),
#  (('магнитный', 'поле'), 302),
#  (('результат', 'работа'), 296),
#  (('углекислый', 'газ'), 291),
#  (('научный', 'работа'), 284),
#  (('приходить', 'вывод'), 281),
#  (('доцент', 'кафедра'), 280),
#  (('2023', 'год'), 279),
#  (('автор', 'статья'), 278),
#  (('миллиард', 'год'), 275),
#  (('образ', 'жизнь'), 274),
#  (('технический', 'наука'), 269),
#  (('который', 'позволять'), 265),
#  (('ниу', 'вшэ'), 258),
#  (('человек', 'который'), 253),
#  (('мочь', 'приводить'), 243),
#  (('исследование', 'ученый'), 236),
#  (('риск', 'развитие'), 226),
#  (('год', 'наш'), 215),
#  (('2021', 'год'), 213),
#  (('2020', 'год'), 213),
#  (('новый', 'статья'), 212),
#  (('солнечный', 'система'), 211),
#  (('наш', 'планета'), 211),
#  (('ученый', 'университет'), 210),
#  (('мочь', 'становиться'), 210),
#  (('свой', 'очередь'), 208),
#  (('изменение', 'климат'), 208),
#  (('получать', 'результат'), 207),
#  (('весь', 'мир'), 205),
#  (('слово', 'ученый'), 204),
#  (('речь', 'идти'), 204),
#  (('приоритет', '2030'), 204),
#  (('головной', 'мозг'), 200),
#  (('градус', 'цельсий'), 197),
#  (('несколько', 'год'), 196),
#  (('световой', 'год'), 196),
#  (('машинный', 'обучение'), 195),
#  (('это', 'происходить'), 193),
#  (('высокий', 'уровень'), 192),
#  (('ученый', 'обнаруживать'), 191),
#  (('группа', 'ученый'), 190),
#  (('первый', 'очередь'), 190),
#  (('темный', 'материя'), 189),
#  (('последний', 'год'), 188),
#  (('ученый', 'проводить'), 187),
#  (('работа', 'ученый'), 187),
#  (('обращать', 'внимание'), 182),
#  (('рамка', 'программа'), 180),
#  (('нервный', 'система'), 179),
#  (('университет', 'сша'), 177),
#  (('проводить', 'эксперимент'), 176),
#  (('весь', 'это'), 175),
#  (('предыдущий', 'исследование'), 174),
#  (('продолжительность', 'жизнь'), 173),
#  (('млечный', 'путь'), 171),
#  (('это', 'самый'), 170),
#  (('иной', 'слово'), 169),
#  (('проводить', 'исследование'), 167),
#  (('научный', 'фонд'), 167),
#  (('of', 'the'), 166),
#  (('ученый', 'использовать'), 165),
#  (('российский', 'научный'), 165),
#  (('сделать', 'вывод'), 164),
#  (('сотрудник', 'лаборатория'), 163),
#  (('получать', 'данные'), 161),
#  (('профессор', 'кафедра'), 161),
#  (('принимать', 'участие'), 159),
#  (('год', 'ученый'), 159),
#  (('миллион', 'человек'), 157),
#  (('журнал', 'science'), 157),
#  (('лидерство', 'приоритет'), 156),
#  (('человек', 'мочь'), 155),
#  (('высокий', 'температура'), 154),
#  (('год', 'это'), 153),
#  (('мочь', 'использовать'), 153),
#  (('представлять', 'журнал'), 152),
#  (('ученый', 'пнип'), 152),
#  (('ученый', 'пермский'), 151),
#  (('век', 'наш'), 151),
#  (('naked', 'science'), 150),
#  (('мнение', 'ученый'), 150),
#  (('кандидат', 'технический'), 150),
#  (('больший', 'часть'), 148),
#  (('ученый', 'предполагать'), 148),
#  (('свой', 'работа'), 147),
#  (('который', 'опубликовывать'), 146),
#  (('результат', 'опубликовывать'), 146),
#  (('это', 'делать'), 145),
#  (('исследование', 'выполнять'), 144),
#  (('2019', 'год'), 144),
#  (('исследование', 'проводить'), 144),
#  (('глобальный', 'потепление'), 144),
#  (('болезнь', 'альцгеймер'), 143),
#  (('поэтому', 'ученый'), 142),
#  (('тысяча', 'человек'), 142),
#  (('долгий', 'время'), 141),
#  (('самый', 'разный'), 140),
#  (('иммунный', 'система'), 140),
#  (('исследование', 'который'), 138),
#  (('физический', 'активность'), 138),
#  (('нейронный', 'сеть'), 137),
#  (('это', 'приводить'), 136),
#  (('это', 'ученый'), 136),
#  (('живой', 'организм'), 136),
#  (('это', 'означать'), 135),
#  (('контрольный', 'группа'), 133),
#  (('государственный', 'университет'), 132),
#  (('математический', 'модель'), 131),
#  (('ведущий', 'научный'), 130),
#  (('питательный', 'вещество'), 129),
#  (('новый', 'метод'), 129),
#  (('это', 'очень'), 129),
#  (('поддерживать', 'грант'), 129),
#  (('важный', 'роль'), 127),
#  (('ученый', 'выяснять'), 127),
#  (('академический', 'лидерство'), 127),
#  (('международный', 'группа'), 126),
#  (('помимо', 'это'), 126),
#  (('программа', 'стратегический'), 126),
#  (('парниковый', 'газ'), 126),
#  (('крайний', 'мера'), 125),
#  (('позволять', 'получать'), 125),
#  (('стратегический', 'академический'), 125),
#  (('база', 'данные'), 124),
#  (('сельский', 'хозяйство'), 124),
#  (('масса', 'тело'), 124),
#  (('настоящий', 'время'), 124),
#  (('выполнять', 'рамка'), 124),
#  (('мочь', 'помогать'), 122),
#  (('работа', 'показывать'), 120),
#  (('небесный', 'тело'), 120),
#  (('исследователь', 'обнаруживать'), 119),
#  (('ученый', 'отмечать'), 118),
#  (('доктор', 'технический'), 118),
#  (('мочь', 'вызывать'), 117),
#  (('наука', 'доцент'), 117),
#  (('который', 'использовать'), 117),
#  (('высокий', 'образование'), 117),
#  (('средний', 'возраст'), 117),
#  (('материал', 'который'), 117),
#  (('отвечать', 'вопрос'), 115),
#  (('мнение', 'автор'), 115),
#  (('давать', 'возможность'), 115),
#  (('scientific', 'reports'), 114),
#  (('система', 'управление'), 114),
#  (('работа', 'выполнять'), 114),
#  (('ученый', 'считать'), 111),
#  (('старший', 'научный'), 111),
#  (('принятие', 'решение'), 110),
#  (('социальный', 'сеть'), 110),
#  (('белый', 'карлик'), 110),
#  (('новый', 'вид'), 110),
#  (('космический', 'телескоп'), 109),
#  (('молодой', 'человек'), 109),
#  (('целый', 'ряд'), 108),
#  (('который', 'находиться'), 107),
#  (('химический', 'состав'), 107),
#  (('нейтронный', 'звезда'), 107),
#  (('эксперимент', 'показывать'), 106),
#  (('научный', 'журнал'), 105),
#  (('журнал', 'scientific'), 105),
#  (('результат', 'показывать'), 105),
#  (('анализ', 'показывать'), 104),
#  (('xx', 'век'), 104),
#  (('вещество', 'который'), 104),
#  (('прошлый', 'год'), 104),
#  (('длина', 'волна'), 103),
#  (('это', 'значить'), 103),
#  (('каждый', 'год'), 102),
#  (('группа', 'исследователь'), 102),
#  (('отмечать', 'автор'), 102),
#  (('решать', 'проблема'), 101),
#  (('мужчина', 'женщина'), 101),
#  (('человек', 'это'), 100),
#  (('позволять', 'определять'), 100),
#  (('ученый', 'приходить'), 99),
#  (('наш', 'день'), 99),
#  (('xix', 'век'), 99),
#  (('наш', 'страна'), 99),
#  (('психический', 'здоровье'), 99),
#  (('разный', 'вид'), 97),
#  (('низкий', 'температура'), 97),
#  (('свой', 'род'), 97),
#  (('пять', 'год'), 97),
#  (('руководитель', 'проект'), 97),
#  (('университет', 'великобритания'), 96),
#  (('который', 'иметь'), 96),
#  (('большой', 'часть'), 96),
#  (('работа', 'который'), 96),
#  (('статья', 'результат'), 96),
#  (('статья', 'который'), 96),
#  (('выходить', 'журнал'), 95),
#  (('который', 'получать'), 95),
#  (('калифорнийский', 'университет'), 95),
#  (('финансовый', 'поддержка'), 94),
#  (('proceedings', 'of'), 94),
#  (('исследователь', 'изучать'), 94),
#  (('делать', 'это'), 94),
#  (('ученый', 'проанализировать'), 94),
#  (('космический', 'луч'), 93),
#  (('это', 'первый'), 93),
#  (('наш', 'исследование'), 93),
#  (('низкий', 'уровень'), 93),
#  (('nature', 'communications'), 92),
#  (('2018', 'год'), 92),
#  (('также', 'ученый'), 92),
#  (('основной', 'причина'), 92),
#  (('опубликовывать', 'journal'), 91),
#  (('это', 'помогать'), 91),
#  (('журнал', 'plos'), 91),
#  (('пожилой', 'человек'), 91),
#  (('который', 'работать'), 90),
#  (('модель', 'который'), 90),
#  (('решение', 'проблема'), 90),
#  (('побочный', 'эффект'), 89),
#  (('сегодняшний', 'день'), 89),
#  (('повышать', 'риск'), 89),
#  (('2016', 'год'), 89),
#  (('мнение', 'исследователь'), 88),
#  (('самый', 'крупный'), 88),
#  (('слово', 'автор'), 88),
#  (('журнал', 'proceedings'), 88),
#  (('возраст', 'год'), 88),
#  (('результат', 'который'), 88),
#  (('система', 'который'), 87),
#  (('когнитивный', 'способность'), 87),
#  (('команда', 'ученый'), 87),
#  (('ученый', 'также'), 87),
#  (('жизнь', 'человек'), 87),
#  (('горный', 'порода'), 87),
#  (('ученый', 'исследовать'), 87),
#  (('реальный', 'время'), 86),
#  (('именно', 'поэтому'), 86),
#  (('когнитивный', 'функция'), 86),
#  (('стоить', 'отмечать'), 86),
#  (('соавтор', 'исследование'), 86),
#  (('снижать', 'риск'), 86),
#  (('дальнейший', 'исследование'), 86),
#  (('тысяча', 'километр'), 85),
#  (('наука', 'профессор'), 85),
#  (('красный', 'планета'), 85),
#  (('science', 'advances'), 84),
#  (('однако', 'это'), 84),
#  (('северный', 'америка'), 84),
#  (('ученый', 'удаваться'), 84),
#  (('молочный', 'железа'), 83),
#  (('грант', 'рнф'), 83),
#  (('самый', 'большой'), 83),
#  (('верхний', 'слой'), 83),
#  (('играть', 'важный'), 83),
#  (('связь', 'это'), 83),
#  (('статья', 'журнал'), 83),
#  (('использовать', 'качество'), 83),
#  (('здоровье', 'человек'), 82),
#  (('широкий', 'спектр'), 82),
#  (('90', 'процент'), 82),
#  (('большой', 'взрыв'), 82),
#  (('мочь', 'возникать'), 82),
#  (('помощь', 'который'), 82),
#  (('позволять', 'оценивать'), 82),
#  (('организм', 'человек'), 82),
#  (('химический', 'реакция'), 81),
#  (('ученый', 'предлагать'), 81),
#  (('наш', 'работа'), 81),
#  (('новый', 'способ'), 81),
#  (('ответ', 'вопрос'), 81),
#  (('ученый', 'показывать'), 81),
#  (('который', 'помогать'), 81),
#  (('самый', 'ранний'), 81),
#  (('огромный', 'количество'), 80),
#  (('ученый', 'смочь'), 80),
#  (('10', 'процент'), 80),
#  (('мочь', 'использоваться'), 80),
#  (('мочь', 'связанный'), 80),
#  (('мочь', 'иметь'), 80),
#  (('грант', 'российский'), 80),
#  (('первый', 'автор'), 80),
#  (('информационный', 'технология'), 80),
#  (('рассказывать', 'автор'), 79),
#  (('ученый', 'планировать'), 79),
#  (('это', 'сделать'), 79),
#  (('программный', 'обеспечение'), 79),
#  (('источник', 'энергия'), 79),
#  (('ученый', 'рассматривать'), 79),
#  (('дополнительный', 'исследование'), 79),
#  (('раковый', 'клетка'), 79),
#  (('ученый', 'институт'), 79),
#  (('фактор', 'риск'), 78),
#  (('километр', 'секунда'), 78),
#  (('который', 'происходить'), 78),
#  (('ученый', 'получать'), 78),
#  (('the', 'royal'), 78),
#  (('становиться', 'причина'), 77),
#  (('именно', 'это'), 77),
#  (('последний', 'десятилетие'), 77),
#  (('homo', 'sapiens'), 77),
#  (('20', 'год'), 77),
#  (('свой', 'исследование'), 77),
#  (('исследование', 'поддерживать'), 77),
#  (('входить', 'состав'), 76),
#  (('ученый', 'полагать'), 76),
#  (('автор', 'научный'), 76),
#  (('повышенный', 'риск'), 76),
#  (('новый', 'технология'), 76),
#  (('привлекать', 'внимание'), 76),
#  (('весь', 'время'), 76),
#  (('американский', 'ученый'), 76),
#  (('журнал', 'journal'), 76),
#  (('свой', 'вывод'), 75),
#  (('благодаря', 'это'), 75),
#  (('ученый', 'мочь'), 75),
#  (('конец', 'конец'), 75),
#  (('джеймс', 'уэбб'), 75),
#  (('очень', 'важный'), 75),
#  (('химический', 'вещество'), 75),
#  (('разработка', 'новый'), 75),
#  (('самый', 'высокий'), 75),
#  (('психический', 'расстройство'), 75),
#  (('новый', 'подход'), 74),
#  (('сотня', 'тысяча'), 74),
#  (('несколько', 'десяток'), 74),
#  (('мочь', 'оказываться'), 74),
#  (('который', 'должный'), 74),
#  (('очень', 'большой'), 74),
#  (('который', 'являться'), 74),
#  (('десяток', 'год'), 74),
#  (('научный', 'центр'), 74),
#  (('затем', 'ученый'), 73),
#  (('помощь', 'метод'), 73),
#  (('стволовой', 'клетка'), 73),
#  (('мочь', 'достигать'), 73),
#  (('активность', 'мозг'), 73),
#  (('кроме', 'ученый'), 73),
#  (('100', 'тысяча'), 73),
#  (('2017', 'год'), 73),
#  (('результат', 'эксперимент'), 73),
#  (('химический', 'технология'), 73),
#  (('человек', 'жить'), 73),
#  (('состояние', 'здоровье'), 73),
#  (('однако', 'новый'), 73),
#  (('это', 'говорить'), 72),
#  (('ранее', 'ученый'), 72),
#  (('ученый', 'опубликовывать'), 72),
#  (('выполнять', 'поддержка'), 72),
#  (('область', 'мозг'), 72),
#  (('проводить', 'рамка'), 72),
#  (('некоторый', 'время'), 72),
#  (('данный', 'момент'), 72),
#  (('широко', 'распространять'), 72),
#  (('топливный', 'элемент'), 72),
#  (('анализ', 'данные'), 71),
#  (('2024', 'год'), 71),
#  (('второй', 'половина'), 71),
#  (('значительный', 'часть'), 71),
#  (('тяжелый', 'металл'), 71),
#  (('отмечать', 'ученый'), 70),
#  (('участник', 'эксперимент'), 70),
#  (('большинство', 'случай'), 70),
#  (('эксперимент', 'ученый'), 70),
#  (('процесс', 'который'), 70),
#  (('основной', 'часть'), 70),
#  (('научный', 'сообщество'), 70),
#  (('вполне', 'мочь'), 70),
#  (('новый', 'материал'), 70),
#  (('красный', 'карлик'), 70),
#  (('последний', 'время'), 70),
#  (('обратный', 'связь'), 70),
#  (('это', 'связывать'), 70),
#  (('позволять', 'создавать'), 69),
#  (('компьютерный', 'моделирование'), 69),
#  (('метод', 'позволять'), 69),
#  (('разный', 'страна'), 69),
#  (('электрический', 'поле'), 69),
#  (('время', 'который'), 69),
#  (('органический', 'соединение'), 69),
#  (('лежать', 'основа'), 68),
#  (('старший', 'преподаватель'), 68),
#  (('журнал', 'вестник'), 68),
#  (('младший', 'научный'), 68),
#  (('заведующий', 'лаборатория'), 68),
#  (('несколько', 'день'), 68),
#  (('xxi', 'век'), 68),
#  (('наука', 'высокий'), 68),
#  (('международный', 'команда'), 68),
#  (('решение', 'задача'), 68),
#  (('уровень', 'море'), 68),
#  (('жидкий', 'вода'), 68),
#  (('общий', 'сложность'), 68),
#  (('рак', 'молочный'), 68),
#  (('небольшой', 'количество'), 68),
#  (('ключевой', 'роль'), 68),
#  (('александр', 'марков'), 68),
#  (('сверхмассивный', 'черный'), 67),
#  (('метод', 'лечение'), 67),
#  (('исследователь', 'предполагать'), 67),
#  (('университет', 'штат'), 67),
#  (('исследователь', 'отмечать'), 67),
#  (('ученый', 'разрабатывать'), 67),
#  (('министерство', 'наука'), 67),
#  (('химический', 'элемент'), 67),
#  (('каждый', 'день'), 67),
#  (('ученый', 'изучать'), 67),
#  (('рассказывать', 'руководитель'), 67),
#  (('нервный', 'клетка'), 67),
#  (('мировой', 'океан'), 67),
#  (('мочь', 'влиять'), 67),
#  (('древний', 'человек'), 67),
#  (('вид', 'животное'), 67),
#  (('десять', 'год'), 66),
#  (('50', 'процент'), 66),
#  (('использовать', 'метод'), 66),
#  (('академия', 'наука'), 66),
#  (('тихий', 'океан'), 66),
#  (('royal', 'society'), 66),
#  (('высокий', 'содержание'), 66),
#  (('10', 'тысяча'), 66),
#  (('становиться', 'первый'), 66),
#  (('газовый', 'гигант'), 66),
#  (('современный', 'человек'), 66),
#  (('животное', 'который'), 66),
#  (('самый', 'древний'), 66),
#  (('некоторый', 'случай'), 66),
#  (('новый', 'поколение'), 66),
#  (('солнечный', 'свет'), 66),
#  (('журнал', 'the'), 65),
#  (('который', 'человек'), 65),
#  (('составлять', 'около'), 65),
#  (('некоторый', 'вид'), 65),
#  (('работа', 'проводить'), 65),
#  (('очень', 'высокий'), 65),
#  (('научный', 'исследование'), 65),
#  (('который', 'образовываться'), 65),
#  (('30', 'год'), 65),
#  (('который', 'способный'), 65),
#  (('plos', 'one'), 65),
#  (('коричневый', 'карлик'), 65),
#  (('50', 'год'), 64),
#  (('наш', 'галактика'), 64),
#  (('ученый', 'устанавливать'), 64),
#  (('большой', 'число'), 64),
#  (('это', 'использовать'), 64),
#  (('самый', 'распространенный'), 64),
#  (('ход', 'исследование'), 64),
#  (('ученый', 'сделать'), 64),
#  (('разрабатывать', 'новый'), 64),
#  (('который', 'представлять'), 64),
#  (('большой', 'объем'), 64),
#  (('подавлять', 'большинство'), 64),
#  (('весь', 'остальной'), 64),
#  (('заведующий', 'кафедра'), 64),
#  (('принимать', 'решение'), 64),
#  (('ученый', 'находить'), 63),
#  (('негативный', 'последствие'), 63),
#  (('20', 'процент'), 63),
#  (('иммунный', 'ответ'), 63),
#  (('2015', 'год'), 63),
#  (('набор', 'данные'), 63),
#  (('выброс', 'парниковый'), 63),
#  (('первый', 'взгляд'), 63),
#  (('1942', 'год'), 63),
#  (('иметь', 'высокий'), 63),
#  (('исследование', 'проводиться'), 63),
#  (('егор', 'быковский'), 63),
#  (('программа', 'академический'), 63),
#  (('клетка', 'который'), 62),
#  (('данные', 'который'), 62),
#  (('следующий', 'этап'), 62),
#  (('высокий', 'точность'), 62),
#  (('astrophysical', 'journal'), 62),
#  (('который', 'становиться'), 62),
#  (('исследователь', 'университет'), 62),
#  (('свой', 'жизнь'), 62),
#  (('доктор', 'наука'), 62),
#  (('это', 'свой'), 62),
#  (('процент', 'случай'), 62),
#  (('серьезный', 'проблема'), 62),
#  (('развитие', 'рак'), 62),
#  (('играть', 'роль'), 62),
#  (('сточный', 'вода'), 62),
#  (('результат', 'анализ'), 62),
#  (('молекула', 'который'), 62),
#  (('ученый', 'оценивать'), 62),
#  (('высокий', 'скорость'), 61),
#  (('второй', 'тип'), 61),
#  (('который', 'использоваться'), 61),
#  (('который', 'возникать'), 61),
#  (('проводить', 'анализ'), 61),
#  (('результат', 'ученый'), 61),
#  (('наука', 'технология'), 61),
#  (('иметь', 'большой'), 61),
#  (('это', 'связанный'), 61),
#  (('здоровый', 'человек'), 61),
#  (('миллион', 'тонна'), 61),
#  (('температура', 'тело'), 61),
#  (('который', 'проводить'), 61),
#  (('открывать', 'новый'), 61),
#  (('федеральный', 'университет'), 61),
#  (('ведущий', 'автор'), 61),
#  (('это', 'рассказываться'), 61),
#  (('академический', 'стратегический'), 61),
#  (('стратегический', 'лидерство'), 61),
#  (('елена', 'наймарк'), 61),
#  (('течение', 'несколько'), 60),
#  (('разработка', 'проводить'), 60),
#  (('научный', 'группа'), 60),
#  (('качество', 'жизнь'), 60),
#  (('наш', 'предок'), 60),
#  (('риск', 'смерть'), 60),
#  (('автор', 'отмечать'), 60),
#  (('мочь', 'происходить'), 60),
#  (('домашний', 'животное'), 60),
#  (('который', 'давать'), 60),
#  (('весь', 'причина'), 60),
#  (('исследовательский', 'центр'), 60),
#  (('онкологический', 'заболевание'), 60),
#  (('хронический', 'заболевание'), 60),
#  (('предлагать', 'использовать'), 60),
#  (('рассказываться', 'статья'), 60),
#  (('год', 'время'), 59),
#  (('миллиард', 'доллар'), 59),
#  (('ученый', 'определять'), 59),
#  (('который', 'состоять'), 59),
#  (('часто', 'встречаться'), 59),
#  (('новый', 'данные'), 59),
#  (('исследование', 'участвовать'), 59),
#  (('исследование', 'позволять'), 59),
#  (('процент', 'весь'), 59),
#  (('среда', 'обитание'), 59),
#  (('развитие', 'заболевание'), 59),
#  (('создание', 'новый'), 59),
#  (('артериальный', 'давление'), 59),
#  (('который', 'ученый'), 59),
#  (('технология', 'позволять'), 59),
#  (('вывод', 'приходить'), 59),
#  (('коренной', 'народ'), 59),
#  (('frontiers', 'in'), 58),
#  (('данный', 'случай'), 58),
#  (('который', 'включать'), 58),
#  (('ученый', 'это'), 58),
#  (('человек', 'часто'), 58),
#  (('несколько', 'сотня'), 58),
#  (('сделать', 'это'), 58),
#  (('километр', 'час'), 58),
#  (('команда', 'исследователь'), 58),
#  (('который', 'проходить'), 58),
#  (('год', 'который'), 58),
#  (('сотрудник', 'институт'), 58),
#  (('слово', 'исследователь'), 58),
#  (('практически', 'весь'), 58),
#  (('который', 'приводить'), 58),
#  (('большой', 'значение'), 58),
#  (('сразу', 'несколько'), 58),
#  (('тяжелый', 'элемент'), 58),
#  (('приводить', 'появление'), 58),
#  (('десяток', 'тысяча'), 58),
#  (('летучий', 'мышь'), 58),
#  (('термоядерный', 'реакция'), 58),
#  (('научный', 'статья'), 57),
#  (('жизненный', 'цикл'), 57),
#  (('который', 'называть'), 57),
#  (('фактор', 'который'), 57),
#  (('год', 'однако'), 57),
#  (('вывод', 'ученый'), 57),
#  (('ученый', 'выявлять'), 57),
#  (('который', 'показывать'), 57),
#  (('протяжение', 'весь'), 57),
#  (('электрический', 'ток'), 57),
#  (('человек', 'возраст'), 57),
#  (('поддержка', 'российский'), 57),
#  (('всемирный', 'организация'), 57),
#  (('организация', 'здравоохранение'), 57),
#  (('мочь', 'служить'), 57),
#  (('свойство', 'материал'), 57),
#  (('морской', 'вода'), 57),
#  (('80', 'процент'), 57),
#  (('фактор', 'влиять'), 57),
#  (('ученый', 'представлять'), 57),
#  (('особый', 'внимание'), 57),
#  (('миллион', 'доллар'), 57),
#  (('преподаватель', 'кафедра'), 57),
#  (('40', 'процент'), 56),
#  (('также', 'мочь'), 56),
#  (('выполнять', 'финансовый'), 56),
#  (('квадратный', 'километр'), 56),
#  (('который', 'участвовать'), 56),
#  (('который', 'смочь'), 56),
#  (('новый', 'зеландия'), 56),
#  (('это', 'большой'), 56),
#  (('несколько', 'месяц'), 56),
#  (('academy', 'of'), 56),
#  (('вечный', 'мерзлота'), 56),
#  (('мочь', 'полезный'), 56),
#  (('полезный', 'нагрузка'), 56),
#  (('однако', 'сей'), 56),
#  (('природный', 'газ'), 56),
#  (('белок', 'который'), 56),
#  (('который', 'вызывать'), 56),
#  (('исследование', 'мочь'), 56),
#  (('органический', 'вещество'), 56),
#  (('российский', 'федерация'), 56),
#  (('высокий', 'давление'), 56),
#  (('высокий', 'концентрация'), 56),
#  (('эксперимент', 'проводить'), 56),
#  (('каждый', 'который'), 56),
#  (('журнал', 'frontiers'), 55),
#  (('прима', 'ред'), 55),
#  (('исследование', 'также'), 55),
#  (('университет', 'имя'), 55),
#  (('человек', 'весь'), 55),
#  (('это', 'указывать'), 55),
#  (('слой', 'атмосфера'), 55),
#  (('астрономический', 'единица'), 55),
#  (('любой', 'случай'), 55),
#  (('высокий', 'показатель'), 55),
#  (('высокий', 'риск'), 55),
#  (('развитие', 'болезнь'), 55),
#  (('дикий', 'природа'), 55),
#  (('год', 'весь'), 55),
#  (('позволять', 'предполагать'), 55),
#  (('кафедра', 'химический'), 55),
#  (('клинический', 'испытание'), 55),
#  (('это', 'показывать'), 55),
#  (('течение', 'год'), 55),
#  (('повышать', 'эффективность'), 55),
#  (('ледниковый', 'период'), 55),
#  (('однако', 'ученый'), 55),
#  (('римский', 'империя'), 55),
#  (('первый', 'этап'), 55),
#  (('вид', 'который'), 54),
#  (('вывод', 'представлять'), 54),
#  (('метод', 'который'), 54),
#  (('поиск', 'новый'), 54),
#  (('болезнь', 'паркинсон'), 54),
#  (('это', 'лишь'), 54),
#  (('участник', 'исследование'), 54),
#  (('ген', 'который'), 54),
#  (('создавать', 'новый'), 54),
#  (('руководитель', 'исследование'), 54),
#  (('вне', 'зависимость'), 54),
#  (('южный', 'америка'), 54),
#  (('the', 'national'), 54),
#  (('national', 'academy'), 54),
#  (('это', 'исследователь'), 54),
#  (('исследование', 'принимать'), 54),
#  (('причина', 'смерть'), 54),
#  (('время', 'время'), 54),
#  (('исследование', 'представлять'), 54),
#  (('который', 'также'), 54),
#  (('это', 'просто'), 54),
#  (('поверхность', 'земля'), 54),
#  (('это', 'важный'), 54),
#  (('территория', 'современный'), 54),
#  (('каменный', 'орудие'), 54),
#  (('населенный', 'пункт'), 54),
#  (('вращаться', 'вокруг'), 54),
#  (('разделять', 'группа'), 53),
#  (('наиболее', 'эффективный'), 53),
#  (('обладать', 'высокий'), 53),
#  (('вместо', 'это'), 53),
#  (('близкий', 'родственник'), 53),
#  (('весь', 'жизнь'), 53),
#  (('сотрудник', 'центр'), 53),
#  (('of', 'sciences'), 53),
#  (('достаточный', 'количество'), 53),
#  (('помогать', 'понимать'), 53),
#  (('важный', 'фактор'), 53),
#  (('решать', 'проверять'), 53),
#  (('проект', 'поддерживать'), 53),
#  (('позволять', 'использовать'), 53),
#  (('прошлый', 'век'), 53),
#  (('который', 'обеспечивать'), 53),
#  (('который', 'часто'), 53),
#  (('который', 'свой'), 53),
#  (('это', 'подтверждать'), 53),
#  (('исследователь', 'проводить'), 53),
#  (('журнал', 'pnas'), 52),
#  (('срок', 'служба'), 52),
#  (('режим', 'работа'), 52),
#  (('медицинский', 'школа'), 52),
#  (('биологический', 'наука'), 52),
#  (('роль', 'играть'), 52),
#  (('nature', 'astronomy'), 52),
#  (('год', 'исследователь'), 52),
#  (('среди', 'который'), 52),
#  (('дыхательный', 'путь'), 52),
#  (('который', 'составлять'), 52),
#  (('30', 'процент'), 52),
#  (('многий', 'человек'), 52),
#  (('снижение', 'уровень'), 52),
#  (('индекс', 'масса'), 52),
#  (('исследователь', 'также'), 52),
#  (('избыточный', 'вес'), 52),
#  (('год', 'большой'), 52),
#  (('среди', 'прочее'), 52),
#  (('2014', 'год'), 52),
#  (('70', 'процент'), 52),
#  (('наиболее', 'распространять'), 51),
#  (('который', 'создавать'), 51),
#  (('температура', 'поверхность'), 51),
#  (('ранний', 'стадия'), 51),
#  (('10', 'год'), 51),
#  (('который', 'ранее'), 51),
#  (('рамка', 'проект'), 51),
#  (('космический', 'аппарат'), 51),
#  (('позволять', 'ученый'), 51),
#  (('размер', 'тело'), 51),
#  (('различный', 'вид'), 51),
#  (('головной', 'боль'), 51),
#  (('употребление', 'алкоголь'), 51),
#  (('проанализировать', 'данный'), 51),
#  (('позволять', 'снижать'), 51),
#  (('первый', 'ступень'), 51),
#  (('данные', 'показывать'), 51),
#  (('технологический', 'институт'), 51),
#  (('нияу', 'мифь'), 51),
#  (('научный', 'руководитель'), 51),
#  (('водяной', 'пар'), 51),
#  (('гравитационный', 'волна'), 51),
#  (('иммунный', 'клетка'), 51),
#  (('система', 'мочь'), 51),
#  (('время', 'ученый'), 51),
#  (('полезный', 'ископаемое'), 51),
#  (('среда', 'который'), 51),
#  (('который', 'жить'), 51),
#  (('экспрессия', 'ген'), 50),
#  (('красный', 'смещение'), 50),
#  (('который', 'обычно'), 50),
#  (('результат', 'мочь'), 50),
#  (('общий', 'предок'), 50),
#  (('опубликовывать', 'the'), 50),
#  (('international', 'journal'), 50),
#  (('позволять', 'сделать'), 50),
#  (('солнечный', 'ветер'), 50),
#  (('тропический', 'лес'), 50),
#  (('60', 'процент'), 50),
#  (('часть', 'тело'), 50),
#  (('аспирант', 'кафедра'), 50),
#  (('русский', 'язык'), 50),
#  (('проводить', 'серия'), 50),
#  (('физический', 'нагрузка'), 50),
#  (('использовать', 'данные'), 50),
#  (('экспериментальный', 'данные'), 50),
#  (('живой', 'существо'), 50),
#  (('подход', 'позволять'), 50),
#  (('кристаллический', 'решетка'), 50),
#  (('наш', 'результат'), 50),
#  (('проблема', 'здоровье'), 49),
#  (('год', 'жизнь'), 49),
#  (('исследователь', 'считать'), 49),
#  (('важно', 'понимать'), 49),
#  (('пять', 'процент'), 49),
#  (('ученый', 'называть'), 49),
#  (('согласно', 'который'), 49),
#  (('уровень', 'образование'), 49),
#  (('человек', 'год'), 49),
#  (('год', 'становиться'), 49),
#  (('который', 'затем'), 49),
#  (('бронзовый', 'век'), 49),
#  (('автоматизированный', 'система'), 49),
#  (('исследование', 'профессор'), 49),
#  (('находить', 'применение'), 49),
#  (('рассказывать', 'доцент'), 49),
#  (('рамка', 'реализация'), 49),
#  (('редкоземельный', 'элемент'), 49),
#  (('математический', 'моделирование'), 48),
#  (('высокий', 'плотность'), 48),
#  (('технология', 'который'), 48),
#  (('уровень', 'доход'), 48),
#  (('часто', 'использовать'), 48),
#  (('лабораторный', 'условие'), 48),
#  (('весь', 'видимость'), 48),
#  (('ранний', 'этап'), 48),
#  (('40', 'год'), 48),
#  (('несколько', 'неделя'), 48),
#  (('болезнь', 'сердце'), 48),
#  (('изучать', 'влияние'), 48),
#  (('летательный', 'аппарат'), 48),
#  (('национальный', 'центр'), 48),
#  (('повышение', 'уровень'), 47),
#  (('позволять', 'выявлять'), 47),
#  (('the', 'astrophysical'), 47),
#  (('опубликовывать', 'сборник'), 47),
#  (('подводить', 'итог'), 47),
#  (('широко', 'использовать'), 47),
#  (('мочь', 'получать'), 47),
#  (('оба', 'пол'), 47),
#  (('загрязнение', 'воздух'), 47),
#  (('исследование', 'область'), 47),
#  (('звезда', 'который'), 47),
#  (('мочь', 'работать'), 47),
#  (('исследователь', 'планировать'), 47),
#  (('композиционный', 'материал'), 47),
#  (('больший', 'вероятность'), 47),
#  (('главный', 'образ'), 47),
#  (('сша', 'решать'), 47),
#  (('наш', 'организм'), 47),
#  (('очень', 'похожий'), 47),
#  (('серия', 'эксперимент'), 47),
#  (('позволять', 'понимать'), 47),
#  (('женщина', 'который'), 47),
#  (('соединение', 'который'), 47),
#  (('получать', 'помощь'), 47),
#  (('весь', 'вид'), 47),
#  (('большой', 'расстояние'), 47),
#  (('космический', 'корабль'), 47),
#  (('50', 'тысяча'), 47),
#  (('свой', 'время'), 47),
#  (('экономический', 'наука'), 47),
#  (('который', 'определять'), 47),
#  (('вода', 'который'), 47),
#  (('исследовательский', 'группа'), 46),
#  (('комнатный', 'температура'), 46),
#  (('ученый', 'решать'), 46),
#  (('причина', 'который'), 46),
#  (('сотня', 'миллион'), 46),
#  (('второй', 'группа'), 46),
#  (('аллергический', 'реакция'), 46),
#  (('условие', 'который'), 46),
#  (('разный', 'тип'), 46),
#  (('каждый', 'человек'), 46),
#  (('использовать', 'данный'), 46),
#  (('весь', 'участник'), 46),
#  (('течение', 'время'), 46),
#  (('объяснять', 'автор'), 46),
#  (('многий', 'вид'), 46),
#  (('мочь', 'сказать'), 46),
#  (('вестник', 'пнип'), 46),
#  (('человек', 'животное'), 46),
#  (('лекарственный', 'препарат'), 46),
#  (('средний', 'температура'), 46),
#  (('журнал', 'current'), 46),
#  (('взрослый', 'человек'), 46),
#  (('мочь', 'находить'), 46),
#  (('время', 'год'), 46),
#  (('шесть', 'месяц'), 46),
#  (('время', 'эксперимент'), 46),
#  (('директор', 'центр'), 46),
#  (('молодой', 'ученый'), 46),
#  (('передача', 'данные'), 46),
#  (('вакцина', 'против'), 46),
#  (('химический', 'соединение'), 45),
#  (('разрабатывать', 'ученый'), 45),
#  (('процесс', 'происходить'), 45),
#  (('макс', 'планк'), 45),
#  (('первый', 'группа'), 45),
#  (('режим', 'реальный'), 45),
#  (('сложный', 'задача'), 45),
#  (('исследователь', 'проанализировать'), 45),
#  (('число', 'человек'), 45),
#  (('самый', 'важный'), 45),
#  (('мочь', 'повлиять'), 45),
#  (('очень', 'мало'), 45),
#  (('разрабатывать', 'модель'), 45),
#  (('фонд', 'рнф'), 45),
#  (('рано', 'поздно'), 45),
#  (('помощь', 'специальный'), 45),
#  (('продукт', 'питание'), 45),
#  (('кровеносный', 'сосуд'), 45),
#  (('кандидат', 'наука'), 45),
#  (('композитный', 'материал'), 45),
#  (('повышение', 'температура'), 45),
#  (('элемент', 'который'), 45),
#  (('получать', 'новый'), 45),
#  (('исследование', 'автор'), 45),
#  (('рынок', 'труд'), 45),
#  (('2010', 'год'), 45),
#  (('который', 'относиться'), 45),
#  (('четыре', 'год'), 45),
#  (('вид', 'рак'), 45),
#  (('получать', 'информация'), 45),
#  (('северный', 'полушарие'), 45),
#  (('мочь', 'указывать'), 44),
#  (('совместно', 'коллега'), 44),
#  (('решать', 'задача'), 44),
#  (('работа', 'представлять'), 44),
#  (('вывод', 'исследователь'), 44),
#  (('генетический', 'материал'), 44),
#  (('археолог', 'находить'), 44),
#  (('считать', 'это'), 44),
#  (('температура', 'давление'), 44),
#  (('костный', 'ткань'), 44),
#  (('мозг', 'который'), 44),
#  (('это', 'становиться'), 44),
#  (('илона', 'маск'), 44),
#  (('особенно', 'важный'), 44),
#  (('год', 'земля'), 44),
#  (('рнф', 'опубликовывать'), 44),
#  (('который', 'входить'), 44),
#  (('расчет', 'показывать'), 44),
#  (('задача', 'который'), 44),
#  (('охрана', 'окружающий'), 44),
#  (('предлагать', 'новый'), 44),
#  (('самый', 'начало'), 44),
#  (('также', 'показывать'), 44),
#  (('цифровой', 'технология'), 44),
#  (('земной', 'кора'), 44),
#  (('возраст', 'который'), 44),
#  (('дальний', 'восток'), 44),
#  (('высокий', 'разрешение'), 44),
#  (('согласно', 'результат'), 44),
#  (('питательный', 'среда'), 44),
#  (('многий', 'страна'), 44),
#  (('пермский', 'край'), 44),
#  (('заработный', 'плата'), 44),
#  (('коллега', 'опубликовывать'), 44),
#  (('процент', 'это'), 43),
#  (('широко', 'использоваться'), 43),
#  (('больший', 'количество'), 43),
#  (('удаваться', 'находить'), 43),
#  (('новый', 'научный'), 43),
#  (('строительный', 'материал'), 43),
#  (('жизнь', 'земля'), 43),
#  (('данные', 'наблюдение'), 43),
#  (('ученый', 'создавать'), 43),
#  (('первый', 'случай'), 43),
#  (('эксперимент', 'участвовать'), 43),
#  (('ультрафиолетовый', 'излучение'), 43),
#  (('инфракрасный', 'диапазон'), 43),
#  (('мочь', 'давать'), 43),
#  (('самый', 'популярный'), 43),
#  (('час', 'день'), 43),
#  (('результат', 'получать'), 43),
#  (('приводить', 'снижение'), 43),
#  (('мочь', 'снижать'), 43),
#  (('атмосфера', 'земля'), 43),
#  (('ученый', 'собирать'), 43),
#  (('бронхиальный', 'астма'), 43),
#  (('который', 'делать'), 43),
#  (('исследование', 'становиться'), 43),
#  (('проливать', 'свет'), 43),
#  (('год', 'год'), 43),
#  (('форма', 'жизнь'), 43),
#  (('мочь', 'сделать'), 43),
#  (('ученый', 'замечать'), 43),
#  (('побочный', 'продукт'), 43),
#  (('current', 'biology'), 43),
#  (('показывать', 'человек'), 43),
#  (('это', 'касаться'), 43),
#  (('крупный', 'животное'), 43),
#  (('пресный', 'вода'), 43),
#  (('период', 'время'), 43),
#  (('диабет', 'второй'), 43),
#  (('технологический', 'процесс'), 43),
#  (('2030', 'статья'), 43),
#  (('находить', 'способ'), 42),
#  (('различный', 'тип'), 42),
#  (('эксперимент', 'который'), 42),
#  (('вопрос', 'почему'), 42),
#  (('пищевой', 'продукт'), 42),
#  (('вокруг', 'звезда'), 42),
#  (('большинство', 'человек'), 42),
#  (('исследователь', 'выяснять'), 42),
#  (('кора', 'головной'), 42),
#  (('который', 'удаваться'), 42),
#  (('препринт', 'arxiv'), 42),
#  (('вредный', 'вещество'), 42),
#  (('повышенный', 'уровень'), 42),
#  (('понимать', 'это'), 42),
#  (('внешний', 'вид'), 42),
#  (('группа', 'который'), 42),
#  (('поверхность', 'планета'), 42),
#  (('высокий', 'школа'), 42),
#  (('колледж', 'лондон'), 42),
#  (('данные', 'позволять'), 42),
#  (('вероятность', 'развитие'), 42),
#  (('повседневный', 'жизнь'), 42),
#  (('многий', 'год'), 42),
#  (('модель', 'позволять'), 42),
#  (('данный', 'получать'), 42),
#  ...]
